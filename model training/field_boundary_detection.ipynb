# %% [markdown]
# # Field Boundary Detection with Instance Segmentation
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/field_boundary_detection.ipynb)
#
# This notebook demonstrates an end-to-end pipeline for detecting agricultural field boundaries using instance segmentation with Mask R-CNN. Accurate field boundary delineation is essential for precision agriculture, crop monitoring, subsidy verification, and land use planning.
#
# We use the [Fields of The World (FTW)](https://fieldsofthe.world/) benchmark dataset, which provides Sentinel-2 imagery (4 bands at 10 m resolution) paired with instance segmentation masks across 25 countries. Each chip provides two temporal windows (`window_a` and `window_b`) captured on different dates, so that seasonal vegetation differences can help delineate boundaries. We work with the **india** subset, which is small enough for a tutorial while containing high-quality annotations.
#
# ## Install packages
#
# Uncomment the following line to install the required packages.

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Define a persistent path on your Drive
persistent_dir = '/content/drive/MyDrive/geoai_training'
os.makedirs(persistent_dir, exist_ok=True)

print(f"Models and history will be saved to: {persistent_dir}")
# Out:
# Mounted at /content/drive
# Models and history will be saved to: /content/drive/MyDrive/geoai_training

# %% [markdown]
# ### Suggestions for Long-Running Training
#
# *   **Checkpointing**: Ensure `output_dir` in the training cell (cell `yAfUvgd_KYWJ`) is set to `os.path.join(persistent_dir, 'models')`.
# *   **Validation Split**: Since the session might disconnect, keeping a fixed `val_split` or using a predefined validation set (already provided in the FTW Parquet metadata) ensures consistency across resumes.
# *   **Batch Processing**: For the batch inference part, also point the `output_dir` to Google Drive so you don't lose the generated GeoTIFFs/GeoJSONs.

# %%
import os

# 1. Define paths clearly on Drive
model_save_path = os.path.join(persistent_dir, 'models')
os.makedirs(model_save_path, exist_ok=True)

# 2. Check for an existing checkpoint to resume from
checkpoint_file = os.path.join(model_save_path, 'best_model.pth')
resume_checkpoint = checkpoint_file if os.path.exists(checkpoint_file) else None

if resume_checkpoint:
    print(f"Found existing model at {resume_checkpoint}. Resuming training...")
else:
    print("No existing model found. Starting training from scratch.")

# 3. Enhanced Training Call
geoai.train_instance_segmentation_model(
    images_dir=data["images_dir"],
    labels_dir=data["labels_dir"],
    output_dir=model_save_path,
    num_classes=2,
    num_channels=4,
    batch_size=4,           # Keep batch size small for T4 memory
    num_epochs=50,          # Increased for better accuracy
    learning_rate=0.001,    # Slightly lower for fine-tuning
    val_split=0.2,
    instance_labels=True,
    # model_path=resume_checkpoint, # Hypothetical parameter: check geoai docs if it supports loading weight
    visualize=True,
    verbose=True
)

# %% [markdown]
# ### Pro-Tips for Top-Notch Results:
# - **Early Stopping**: The `geoai` library often saves the `best_model.pth` based on validation loss. Always use that for inference.
# - **Image Augmentation**: If the library supports it, enabling rotations and flips can help the model generalize better to different field orientations.
# - **Monitor VRAM**: If you get an 'Out of Memory' error on the T4, reduce `batch_size` to 2.

# %%
# !pip install geoai-py
# Out:
# Collecting geoai-py
#   Downloading geoai_py-0.36.0-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.0.8)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from geoai-py) (8.3.1)
# Collecting contextily (from geoai-py)
#   Downloading contextily-1.7.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: datasets>=3.0 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.0.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.1.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.7.1)
# Collecting jupyter-server-proxy (from geoai-py)
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting leafmap>=0.57.1 (from geoai-py)
#   Downloading leafmap-0.61.1-py2.py3-none-any.whl.metadata (17 kB)
# Collecting localtileserver (from geoai-py)
#   Downloading localtileserver-0.11.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.10.0)
# Collecting maplibre (from geoai-py)
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.13.0.92)
# Collecting overturemaps (from geoai-py)
#   Downloading overturemaps-0.20.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting planetary-computer (from geoai-py)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from geoai-py) (18.1.0)
# Collecting pystac-client (from geoai-py)
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.5.0)
# Collecting rioxarray (from geoai-py)
#   Downloading rioxarray-0.22.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.6.1)
# Collecting smoothify (from geoai-py)
#   Downloading smoothify-0.2.2-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.0.25)
# Requirement already satisfied: tokenizers>=0.22.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.22.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.10.0+cu128)
# Collecting torchgeo (from geoai-py)
#   Downloading torchgeo-0.9.0-py3-none-any.whl.metadata (19 kB)
# Collecting torchinfo (from geoai-py)
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.67.3)
# Requirement already satisfied: transformers>=4.57.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (3.25.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (2.0.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0->geoai-py) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (4.15.0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.12.45)
# Collecting duckdb>=1.4.1 (from leafmap>=0.57.1->geoai-py)
#   Downloading duckdb-1.5.1-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.20.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (5.2.1)
# Collecting geojson (from leafmap>=0.57.1->geoai-py)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.20.0)
# Collecting ipyvue<1.12.0 (from leafmap>=0.57.1->geoai-py)
#   Downloading ipyvue-1.11.3-py2.py3-none-any.whl.metadata (987 bytes)
# Collecting ipyvuetify (from leafmap>=0.57.1->geoai-py)
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (7.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (5.24.1)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (0.11.0)
# Collecting whiteboxgui (from leafmap>=0.57.1->geoai-py)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py) (2025.11.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py) (0.7.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (1.16.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (6.5.16)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (2.4.1)
# Collecting mercantile (from contextily->geoai-py)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (11.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (1.5.3)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py) (0.12.1)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py) (2.1.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (3.13.3)
# Requirement already satisfied: jupyter-server>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (2.14.0)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->geoai-py)
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (5.7.1)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py) (3.1.3)
# Collecting Flask-Caching (from localtileserver->geoai-py)
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver->geoai-py)
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver->geoai-py)
#   Downloading flask_restx-1.3.2-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver->geoai-py)
#   Downloading rio_tiler-9.0.4-py3-none-any.whl.metadata (11 kB)

# %% [markdown]
# ## Import libraries

# %%
import os
from pathlib import Path
import geopandas as gpd
import geoai

# %% [markdown]
# ## Download the FTW dataset
#
# The [Fields of The World (FTW)](https://fieldsofthe.world/) dataset contains 70,462 samples across 25 countries with Sentinel-2 imagery (4 bands: Red, Green, Blue, NIR at 10 m resolution) and instance segmentation masks. Each chip is 256×256 pixels.
#
# We download the **india** subset, one of the smallest, making it ideal for a tutorial.

# %%
geoai.download_ftw(countries=["india"], output_dir="ftw_data")

# %% [markdown]
# ## Explore the dataset
#
# The FTW dataset includes a GeoParquet file with metadata and geometry for each chip, including the train/val/test split.

# %%
country_dir = os.path.join("ftw_data", "india")
chips_gdf = gpd.read_parquet(os.path.join(country_dir, "chips_india.parquet"))

print(f"Total chips: {len(chips_gdf)}")
print(f"\nSplit distribution:")
print(chips_gdf["split"].value_counts())

# %% [markdown]
# Visualize the spatial distribution of training, validation, and test chips.

# %%
geoai.view_vector_interactive(chips_gdf, column="split")

# %% [markdown]
# Display sample image–mask pairs. Each mask uses unique integer IDs to distinguish individual field instances.

# %%
geoai.display_ftw_samples("ftw_data", country="india", num_samples=4)

# %% [markdown]
# ## Prepare training data
#
# GeoAI's Mask R-CNN pipeline expects `images/` and `labels/` directories with uint8 GeoTIFFs. The `prepare_ftw` function rescales Sentinel-2 reflectance (0–10,000) to uint8 (0–255), organizes files, and prepares test chips.

# %%
data = geoai.prepare_ftw("ftw_data", country="india")
data

# %% [markdown]
# Verify that the prepared tiles look correct.

# %%
geoai.display_training_tiles(
    output_dir="field_boundaries",
    num_tiles=4,
    figsize=(12, 6),
    cmap="tab20",
)

# %% [markdown]
# ## Train instance segmentation model
#
# We train a Mask R-CNN model with a ResNet-50 + FPN backbone.
#
# Key parameters:
# - **`num_classes=2`** — Background (0) and field (1).
# - **`num_channels=4`** — Sentinel-2 bands (R, G, B, NIR). NIR helps distinguish vegetation boundaries.
# - **`instance_labels=True`** — The FTW masks already encode unique instance IDs, so geoai should use them directly instead of running connected-component labeling.
# - **`num_epochs=20`** — Sufficient for demonstration; increase to 50–100 for production.
# - **`val_split=0.2`** — Reserves 20% of chips for validation.

# %%
geoai.train_instance_segmentation_model(
    images_dir=data["images_dir"],
    labels_dir=data["labels_dir"],
    output_dir="field_boundaries/models",
    num_classes=2,
    num_channels=4,
    batch_size=4,
    num_epochs=20,
    learning_rate=0.005,
    val_split=0.2,
    instance_labels=True,
    visualize=True,
    verbose=True,
)

# %% [markdown]
# ## Training performance
#
# Examine the training and validation loss curves to assess model convergence.

# %%
geoai.plot_performance_metrics(
    history_path="field_boundaries/models/training_history.pth",
    figsize=(15, 5),
    verbose=True,
)

# %% [markdown]
# ## Run inference
#
# Apply the trained model to a test image using sliding window inference with window size 256 and overlap 128.

# %%
test_images = sorted(Path(data["test_dir"]).glob("*.tif"))
test_image_path = str(test_images[0])
masks_path = "field_boundary_prediction.tif"
model_path = "field_boundaries/models/best_model.pth"

result = geoai.instance_segmentation(
    input_path=test_image_path,
    output_path=masks_path,
    model_path=model_path,
    num_classes=2,
    num_channels=4,
    window_size=256,
    overlap=128,
    confidence_threshold=0.5,
    batch_size=4,
    vectorize=True,
    class_names=["background", "building"],
)
result

# %% [markdown]
# ## Visualize raw predictions
#
# Each color represents a distinct field instance detected by the model.

# %%
geoai.view_raster(
    result["instance"],
    nodata=0,
    cmap="tab20",
    basemap=test_image_path,
    backend="ipyleaflet",
)

# %%
geoai.view_raster(
    result["class_label"],
    nodata=0,
    cmap="binary",
    basemap=test_image_path,
    backend="ipyleaflet",
)

# %%
geoai.view_raster(
    result["score"], nodata=0, basemap=test_image_path, backend="ipyleaflet"
)

# %%
geoai.view_vector_interactive(result["vector"], tiles=test_image_path, column="score")

# %% [markdown]
# ## Clean instance mask
#
# Remove small spurious detections and fill holes between adjacent instances using `clean_instance_mask`. This is designed specifically for instance segmentation outputs (unlike `clean_raster`, which is for semantic/classification masks).

# %%
cleaned_masks_path = "field_boundary_prediction_cleaned.tif"
geoai.clean_instance_mask(
    result["instance"], cleaned_masks_path, min_area=100, max_hole_area=100
)

# %%
geoai.view_raster(
    cleaned_masks_path,
    nodata=0,
    cmap="tab20",
    basemap=test_image_path,
    backend="ipyleaflet",
)

# %% [markdown]
# ## Vectorize predictions
#
# Convert the cleaned raster mask to vector polygons for spatial analysis.

# %%
output_vector_path = "field_boundary_prediction.geojson"
gdf = geoai.raster_to_vector(cleaned_masks_path, output_vector_path)

# %% [markdown]
# ## Compare predictions with imagery
#
# Use a split map to visually compare the detected field boundaries against the original Sentinel-2 imagery.

# %%
geoai.create_split_map(
    left_layer=gdf,
    right_layer=test_image_path,
    left_args={"style": {"color": "red", "fillOpacity": 0.2}},
    basemap=test_image_path,
)

# %% [markdown]
# ## Geometric properties
#
# Calculate geometric properties for each detected field:
#
# | Property | Description |
# |----------|-------------|
# | **Area** | Field size in hectares — critical for yield estimation and subsidy programs |
# | **Perimeter** | Boundary length — useful for fencing cost estimation |
# | **Elongation** | Major/minor axis ratio — distinguishes strip fields from compact parcels |
# | **Solidity** | Area/convex hull area ratio — measures boundary irregularity |
# | **Extent** | Area/bounding box area ratio — indicates how rectangular a field is |

# %%
gdf_props = geoai.add_geometric_properties(gdf, area_unit="ha", length_unit="m")
gdf_props.head()

# %%
gdf_props.describe()

# %% [markdown]
# ## Visualize fields by property

# %%
geoai.view_vector_interactive(gdf_props, column="area_ha", tiles=test_image_path)

# %%
geoai.view_vector_interactive(gdf_props, column="elongation", tiles=test_image_path)

# %% [markdown]
# ## Batch processing
#
# Process all test images at once.

# %%
geoai.instance_segmentation_batch(
    input_dir=data["test_dir"],
    output_dir="field_boundaries/predictions",
    model_path=model_path,
    num_classes=2,
    num_channels=4,
    window_size=256,
    overlap=128,
    confidence_threshold=0.5,
    batch_size=4,
)

# %% [markdown]
# ## Summary
#
# This notebook demonstrated a complete field boundary detection pipeline:
#
# 1. **Data acquisition** — Downloaded the FTW india dataset with `geoai.download_ftw()`.
# 2. **Data preparation** — Rescaled Sentinel-2 reflectance to uint8 with `geoai.prepare_ftw()`.
# 3. **Training** — Trained Mask R-CNN with `instance_labels=True` to preserve field identity.
# 4. **Inference** — Applied sliding window inference to test imagery.
# 5. **Post-processing** — Cleaned instance masks with `clean_instance_mask()`, then vectorized.
# 6. **Analysis** — Computed geometric properties (area, perimeter, elongation, solidity).
#
# ### Tips for improving results
#
# - **More training data**: Download additional FTW countries with `geoai.download_ftw(countries=["france", "austria"])`.
# - **Both temporal windows**: Use `window="window_b"` in `prepare_ftw()` for a different season, or stack both for 8-band input.
# - **Longer training**: Increase `num_epochs` to 50–100.
# - **Confidence tuning**: Lower `confidence_threshold` (e.g., 0.3) to detect more fields at the cost of more false positives.
# - **Post-processing**: Adjust `min_area` and `max_hole_area` in `clean_instance_mask()` to match your target field sizes.
